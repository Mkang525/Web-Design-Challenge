# %% [markdown]
# # WeatherPy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 648

# %% [markdown]
# ### Perform API Calls
# * Performed a weather check on each city using a series of successive API calls.
# * Included a print log of each city as it's being processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

query_url = f"{url}appid={api_key}&units={units}&q="

city_group=[]
lat = []
lng = []
max_temp = []
hum=[]
cloud=[]
wind=[]
country=[]
date=[]

print("Beginning Data Retrieval\n---------------------------------------")

for city in cities:
    try:
        response = requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        hum.append(response['main']['humidity'])
        cloud.append(response['clouds']['all'])
        wind.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        max_temp.append(response['main']['temp_max'])
        city_group.append(response['name'])
        print(f"Processing Record {cities.index(city)} of Set 1 | {city}")  
        
    except(KeyError, IndexError):
        print("Missing field/result... skipping.")

print("---------------------------------------\nData Retrieval Complete\n---------------------------------------")
# Out:
# Beginning Data Retrieval
# ---------------------------------------
# Processing Record 0 of Set 1 | chokurdakh
# Processing Record 1 of Set 1 | port alfred
# Processing Record 2 of Set 1 | severo-kurilsk
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | khasan
# Processing Record 5 of Set 1 | nishihara
# Processing Record 6 of Set 1 | mehamn
# Processing Record 7 of Set 1 | barrow
# Processing Record 8 of Set 1 | rantepao
# Processing Record 9 of Set 1 | krasnoselkup
# Processing Record 10 of Set 1 | te anau
# Processing Record 11 of Set 1 | laguna
# Processing Record 12 of Set 1 | iqaluit
# Processing Record 13 of Set 1 | geraldton
# Processing Record 14 of Set 1 | lebu
# Processing Record 15 of Set 1 | vaini
# Processing Record 16 of Set 1 | drayton valley
# Processing Record 17 of Set 1 | caluquembe
# Processing Record 18 of Set 1 | shubarshi
# Processing Record 19 of Set 1 | sholapur
# Processing Record 20 of Set 1 | abong mbang
# Processing Record 21 of Set 1 | punta arenas
# Processing Record 22 of Set 1 | aitape
# Processing Record 23 of Set 1 | georgetown
# Processing Record 24 of Set 1 | hilo
# Missing field/result... skipping.
# Processing Record 26 of Set 1 | hermanus
# Processing Record 27 of Set 1 | lompoc
# Processing Record 28 of Set 1 | cape town
# Processing Record 29 of Set 1 | dikson
# Processing Record 30 of Set 1 | talnakh
# Missing field/result... skipping.
# Processing Record 32 of Set 1 | albany
# Processing Record 33 of Set 1 | yellowknife
# Processing Record 34 of Set 1 | berlevag
# Processing Record 35 of Set 1 | vila franca do campo
# Missing field/result... skipping.
# Processing Record 37 of Set 1 | puerto ayora
# Processing Record 38 of Set 1 | svetlogorsk
# Missing field/result... skipping.
# Processing Record 40 of Set 1 | praia da vitoria
# Processing Record 41 of Set 1 | nemuro
# Processing Record 42 of Set 1 | chihuahua
# Processing Record 43 of Set 1 | horconcitos
# Processing Record 44 of Set 1 | rawson
# Processing Record 45 of Set 1 | nichinan
# Processing Record 46 of Set 1 | meulaboh
# Processing Record 47 of Set 1 | zhangye
# Processing Record 48 of Set 1 | sakakah
# Processing Record 49 of Set 1 | san francisco
# Processing Record 50 of Set 1 | rikitea
# Processing Record 51 of Set 1 | butaritari
# Processing Record 52 of Set 1 | arraial do cabo
# Processing Record 53 of Set 1 | naze
# Processing Record 54 of Set 1 | qaanaaq
# Processing Record 55 of Set 1 | kahului
# Processing Record 56 of Set 1 | hluti
# Processing Record 57 of Set 1 | busselton
# Processing Record 58 of Set 1 | dire
# Processing Record 59 of Set 1 | pevek
# Missing field/result... skipping.
# Processing Record 61 of Set 1 | constitucion
# Processing Record 62 of Set 1 | vao
# Processing Record 63 of Set 1 | ribeira grande
# Processing Record 64 of Set 1 | tuktoyaktuk
# Missing field/result... skipping.
# Processing Record 66 of Set 1 | atuona
# Processing Record 67 of Set 1 | ushuaia
# Missing field/result... skipping.
# Processing Record 69 of Set 1 | mitsamiouli
# Processing Record 70 of Set 1 | marsa matruh
# Processing Record 71 of Set 1 | aklavik
# Processing Record 72 of Set 1 | avarua
# Processing Record 73 of Set 1 | longyearbyen
# Processing Record 74 of Set 1 | leningradskiy
# Processing Record 75 of Set 1 | saint george
# Processing Record 76 of Set 1 | flinders
# Processing Record 77 of Set 1 | bilibino
# Processing Record 78 of Set 1 | luderitz
# Processing Record 79 of Set 1 | kununurra
# Processing Record 80 of Set 1 | namie
# Processing Record 81 of Set 1 | bindura
# Processing Record 82 of Set 1 | jaisalmer
# Missing field/result... skipping.
# Processing Record 84 of Set 1 | belaya gora
# Processing Record 85 of Set 1 | springbok
# Processing Record 86 of Set 1 | sistranda
# Processing Record 87 of Set 1 | kapaa
# Processing Record 88 of Set 1 | isangel
# Processing Record 89 of Set 1 | hobart
# Processing Record 90 of Set 1 | bluff
# Processing Record 91 of Set 1 | jamestown
# Processing Record 92 of Set 1 | bonoua
# Processing Record 93 of Set 1 | galesong
# Processing Record 94 of Set 1 | codrington
# Processing Record 95 of Set 1 | mimongo
# Processing Record 96 of Set 1 | pringsewu
# Processing Record 97 of Set 1 | batsfjord
# Processing Record 98 of Set 1 | bartica
# Processing Record 99 of Set 1 | amapa
# Processing Record 100 of Set 1 | ostrovnoy
# Processing Record 101 of Set 1 | tasgaon
# Processing Record 102 of Set 1 | dingle
# Processing Record 103 of Set 1 | flin flon
# Processing Record 104 of Set 1 | lindas
# Missing field/result... skipping.
# Processing Record 106 of Set 1 | esik
# Processing Record 107 of Set 1 | sao domingos
# Processing Record 108 of Set 1 | saint-philippe
# Processing Record 109 of Set 1 | alenquer
# Processing Record 110 of Set 1 | viedma
# Processing Record 111 of Set 1 | aykhal
# Processing Record 112 of Set 1 | yerbogachen
# Processing Record 113 of Set 1 | cidreira
# Processing Record 114 of Set 1 | tasiilaq
# Processing Record 115 of Set 1 | usakos
# Processing Record 116 of Set 1 | rjukan
# Processing Record 117 of Set 1 | provideniya
# Processing Record 118 of Set 1 | ponta do sol
# Processing Record 119 of Set 1 | carnarvon
# Processing Record 120 of Set 1 | lodja
# Processing Record 121 of Set 1 | del rio
# Processing Record 122 of Set 1 | clyde river
# Processing Record 123 of Set 1 | lavrentiya
# Missing field/result... skipping.
# Processing Record 125 of Set 1 | skjervoy
# Processing Record 126 of Set 1 | hithadhoo
# Processing Record 127 of Set 1 | broome
# Missing field/result... skipping.
# Processing Record 129 of Set 1 | atar
# Processing Record 130 of Set 1 | coruripe
# Processing Record 131 of Set 1 | ahipara
# Processing Record 132 of Set 1 | roebourne
# Processing Record 133 of Set 1 | bredasdorp
# Missing field/result... skipping.
# Processing Record 135 of Set 1 | cabo san lucas
# Processing Record 136 of Set 1 | sal rei
# Processing Record 137 of Set 1 | cherskiy
# Processing Record 138 of Set 1 | roald
# Processing Record 139 of Set 1 | honningsvag
# Processing Record 140 of Set 1 | castro
# Processing Record 141 of Set 1 | ormara
# Processing Record 142 of Set 1 | nongan
# Processing Record 143 of Set 1 | thompson
# Processing Record 144 of Set 1 | hofn
# Processing Record 145 of Set 1 | rio gallegos
# Processing Record 146 of Set 1 | west bay
# Processing Record 147 of Set 1 | jacareacanga
# Processing Record 148 of Set 1 | east london
# Processing Record 149 of Set 1 | kasongo
# Processing Record 150 of Set 1 | mar del plata
# Processing Record 151 of Set 1 | eureka
# Processing Record 152 of Set 1 | camana
# Processing Record 153 of Set 1 | bambous virieux
# Processing Record 154 of Set 1 | esperance
# Processing Record 155 of Set 1 | khandyga
# Missing field/result... skipping.
# Processing Record 157 of Set 1 | bull savanna
# Processing Record 158 of Set 1 | buzmeyin
# Processing Record 159 of Set 1 | elbistan
# Processing Record 160 of Set 1 | stephenville
# Processing Record 161 of Set 1 | jining
# Processing Record 162 of Set 1 | sitka
# Processing Record 163 of Set 1 | vila
# Processing Record 164 of Set 1 | komsomolskiy
# Processing Record 165 of Set 1 | bethel
# Processing Record 166 of Set 1 | zeya
# Processing Record 167 of Set 1 | utiel
# Processing Record 168 of Set 1 | adwa
# Processing Record 169 of Set 1 | muros
# Processing Record 170 of Set 1 | nanortalik
# Processing Record 171 of Set 1 | henties bay
# Processing Record 172 of Set 1 | kenai
# Processing Record 173 of Set 1 | correntina
# Processing Record 174 of Set 1 | san quintin
# Processing Record 175 of Set 1 | kavaratti
# Processing Record 176 of Set 1 | christchurch
# Processing Record 177 of Set 1 | brae
# Processing Record 178 of Set 1 | lasa
# Processing Record 179 of Set 1 | eyl
# Processing Record 180 of Set 1 | nikolskoye
# Processing Record 181 of Set 1 | whitecourt
# Processing Record 182 of Set 1 | labuhan
# Processing Record 183 of Set 1 | nago
# Processing Record 184 of Set 1 | katsuura
# Processing Record 185 of Set 1 | hami
# Processing Record 186 of Set 1 | upernavik
# Processing Record 187 of Set 1 | tolaga bay
# Missing field/result... skipping.
# Processing Record 189 of Set 1 | asau
# Processing Record 190 of Set 1 | hukuntsi
# Processing Record 191 of Set 1 | hammerfest
# Processing Record 192 of Set 1 | saskylakh
# Processing Record 193 of Set 1 | bilma
# Processing Record 194 of Set 1 | port hardy
# Processing Record 195 of Set 1 | faanui
# Processing Record 196 of Set 1 | mercedes
# Processing Record 197 of Set 1 | mundo nuevo
# Processing Record 198 of Set 1 | mount gambier
# Processing Record 199 of Set 1 | saint-pierre
# Processing Record 200 of Set 1 | nome
# Processing Record 201 of Set 1 | tuatapere
# Missing field/result... skipping.
# Missing field/result... skipping.
# Processing Record 204 of Set 1 | airai
# Processing Record 205 of Set 1 | asyut
# Processing Record 206 of Set 1 | scarborough
# Processing Record 207 of Set 1 | kamenka
# Processing Record 208 of Set 1 | shenjiamen
# Processing Record 209 of Set 1 | fort nelson
# Processing Record 210 of Set 1 | souillac
# Processing Record 211 of Set 1 | buraydah
# Processing Record 212 of Set 1 | kaniama
# Missing field/result... skipping.
# Processing Record 214 of Set 1 | boueni
# Processing Record 215 of Set 1 | atambua
# Processing Record 216 of Set 1 | lamu
# Processing Record 217 of Set 1 | margate
# Processing Record 218 of Set 1 | novyy buyan
# Processing Record 219 of Set 1 | sao desiderio
# Processing Record 220 of Set 1 | ugoofaaru
# Processing Record 221 of Set 1 | carutapera
# Processing Record 222 of Set 1 | lahad datu
# Processing Record 223 of Set 1 | ola
# Processing Record 224 of Set 1 | torbay
# Processing Record 225 of Set 1 | khatanga
# Processing Record 226 of Set 1 | roma
# Processing Record 227 of Set 1 | stornoway
# Processing Record 228 of Set 1 | portland
# Missing field/result... skipping.
# Processing Record 230 of Set 1 | panorama
# Processing Record 231 of Set 1 | krasnyy oktyabr
# Processing Record 232 of Set 1 | merta
# Processing Record 233 of Set 1 | port hedland
# Processing Record 234 of Set 1 | pavelets
# Processing Record 235 of Set 1 | alausi
# Processing Record 236 of Set 1 | kuching
# Processing Record 237 of Set 1 | deputatskiy
# Processing Record 238 of Set 1 | aracruz
# Processing Record 239 of Set 1 | cuijk
# Processing Record 240 of Set 1 | magadan
# Processing Record 241 of Set 1 | alekseyevsk
# Processing Record 242 of Set 1 | manbij
# Processing Record 243 of Set 1 | rock sound
# Processing Record 244 of Set 1 | khoy
# Processing Record 245 of Set 1 | fukue
# Processing Record 246 of Set 1 | the valley
# Processing Record 247 of Set 1 | axim
# Processing Record 248 of Set 1 | palmer
# Missing field/result... skipping.
# Processing Record 250 of Set 1 | zhigansk
# Missing field/result... skipping.
# Processing Record 252 of Set 1 | jackson
# Processing Record 253 of Set 1 | kodiak
# Processing Record 254 of Set 1 | odweyne
# Processing Record 255 of Set 1 | narsaq
# Processing Record 256 of Set 1 | tupik
# Processing Record 257 of Set 1 | smithers
# Processing Record 258 of Set 1 | pervomayskoye
# Processing Record 259 of Set 1 | usinsk
# Missing field/result... skipping.
# Processing Record 261 of Set 1 | mikun
# Processing Record 262 of Set 1 | sambava
# Processing Record 263 of Set 1 | iquique
# Processing Record 264 of Set 1 | victoria
# Processing Record 265 of Set 1 | imbituba
# Processing Record 266 of Set 1 | mildura
# Missing field/result... skipping.
# Processing Record 268 of Set 1 | bengkulu
# Processing Record 269 of Set 1 | gazli
# Processing Record 270 of Set 1 | tianpeng
# Missing field/result... skipping.
# Processing Record 272 of Set 1 | qurayyat
# Processing Record 273 of Set 1 | padang
# Processing Record 274 of Set 1 | wageningen
# Processing Record 275 of Set 1 | suriapet
# Missing field/result... skipping.
# Processing Record 277 of Set 1 | owatonna
# Processing Record 278 of Set 1 | port elizabeth
# Processing Record 279 of Set 1 | sechura
# Processing Record 280 of Set 1 | pran buri
# Processing Record 281 of Set 1 | yarovoye
# Processing Record 282 of Set 1 | ilulissat
# Processing Record 283 of Set 1 | borba
# Missing field/result... skipping.
# Processing Record 285 of Set 1 | merauke
# Processing Record 286 of Set 1 | moroni
# Processing Record 287 of Set 1 | boizenburg
# Processing Record 288 of Set 1 | phonhong
# Processing Record 289 of Set 1 | touros
# Processing Record 290 of Set 1 | corinto
# Processing Record 291 of Set 1 | klaksvik
# Processing Record 292 of Set 1 | port lincoln
# Processing Record 293 of Set 1 | muroto
# Processing Record 294 of Set 1 | rayagada
# Processing Record 295 of Set 1 | villazon
# Processing Record 296 of Set 1 | adrar
# Processing Record 297 of Set 1 | bago
# Processing Record 298 of Set 1 | guerrero negro
# Processing Record 299 of Set 1 | new norfolk
# Processing Record 300 of Set 1 | penzance
# Processing Record 301 of Set 1 | dakar
# Processing Record 302 of Set 1 | leh
# Processing Record 303 of Set 1 | maridi
# Processing Record 304 of Set 1 | buin
# Processing Record 305 of Set 1 | oussouye
# Processing Record 306 of Set 1 | acapulco
# Processing Record 307 of Set 1 | mount isa
# Missing field/result... skipping.
# Processing Record 309 of Set 1 | aksarka
# Processing Record 310 of Set 1 | dolores
# Processing Record 311 of Set 1 | oktyabrskiy
# Processing Record 312 of Set 1 | sorong
# Processing Record 313 of Set 1 | markapur
# Processing Record 314 of Set 1 | san cristobal
# Processing Record 315 of Set 1 | hlotse
# Processing Record 316 of Set 1 | sekoma
# Missing field/result... skipping.
# Processing Record 318 of Set 1 | arlit
# Processing Record 319 of Set 1 | mahebourg
# Processing Record 320 of Set 1 | manggar
# Processing Record 321 of Set 1 | carbonia
# Processing Record 322 of Set 1 | sterling
# Processing Record 323 of Set 1 | sao jose da coroa grande
# Processing Record 324 of Set 1 | half moon bay
# Processing Record 325 of Set 1 | sur
# Processing Record 326 of Set 1 | makakilo city
# Processing Record 327 of Set 1 | kjollefjord
# Processing Record 328 of Set 1 | olafsvik
# Processing Record 329 of Set 1 | chuy
# Processing Record 330 of Set 1 | kutum
# Processing Record 331 of Set 1 | karpogory
# Processing Record 332 of Set 1 | zheshart
# Processing Record 333 of Set 1 | biloela
# Processing Record 334 of Set 1 | kemin
# Processing Record 335 of Set 1 | becerril
# Processing Record 336 of Set 1 | stryn
# Processing Record 337 of Set 1 | morozovsk
# Processing Record 338 of Set 1 | mersing
# Processing Record 339 of Set 1 | lata
# Processing Record 340 of Set 1 | salalah
# Missing field/result... skipping.
# Processing Record 342 of Set 1 | saint anthony
# Processing Record 343 of Set 1 | tucuman
# Processing Record 344 of Set 1 | freeport
# Processing Record 345 of Set 1 | kosonsoy
# Processing Record 346 of Set 1 | pafos
# Processing Record 347 of Set 1 | quatre cocos
# Processing Record 348 of Set 1 | mogadishu
# Processing Record 349 of Set 1 | cayenne
# Processing Record 350 of Set 1 | jiazi
# Processing Record 351 of Set 1 | ikot ekpene
# Missing field/result... skipping.
# Processing Record 353 of Set 1 | havelock
# Processing Record 354 of Set 1 | westport
# Processing Record 355 of Set 1 | santiago del estero
# Processing Record 356 of Set 1 | bosaso
# Processing Record 357 of Set 1 | tautira
# Processing Record 358 of Set 1 | bonfim
# Missing field/result... skipping.
# Processing Record 360 of Set 1 | kloulklubed
# Processing Record 361 of Set 1 | san jose
# Processing Record 362 of Set 1 | severo-yeniseyskiy
# Processing Record 363 of Set 1 | itarema
# Processing Record 364 of Set 1 | kirakira
# Processing Record 365 of Set 1 | necochea
# Processing Record 366 of Set 1 | chibuto
# Processing Record 367 of Set 1 | kaitangata
# Processing Record 368 of Set 1 | hambantota
# Processing Record 369 of Set 1 | yuanping
# Processing Record 370 of Set 1 | leshukonskoye
# Processing Record 371 of Set 1 | kavieng
# Processing Record 372 of Set 1 | harper
# Processing Record 373 of Set 1 | hamilton
# Processing Record 374 of Set 1 | opochka
# Processing Record 375 of Set 1 | umm lajj
# Processing Record 376 of Set 1 | anuradhapura
# Processing Record 377 of Set 1 | egvekinot
# Processing Record 378 of Set 1 | sharjah
# Processing Record 379 of Set 1 | gamba
# Processing Record 380 of Set 1 | kokkola
# Processing Record 381 of Set 1 | los llanos de aridane
# Processing Record 382 of Set 1 | acarau
# Processing Record 383 of Set 1 | gizo
# Missing field/result... skipping.
# Processing Record 385 of Set 1 | canberra
# Processing Record 386 of Set 1 | contamana
# Processing Record 387 of Set 1 | dudinka
# Missing field/result... skipping.
# Processing Record 389 of Set 1 | ancud
# Processing Record 390 of Set 1 | mago
# Processing Record 391 of Set 1 | aleppo
# Processing Record 392 of Set 1 | moa
# Missing field/result... skipping.
# Processing Record 394 of Set 1 | dunedin
# Processing Record 395 of Set 1 | serenje
# Processing Record 396 of Set 1 | rio branco
# Processing Record 397 of Set 1 | port arthur
# Processing Record 398 of Set 1 | kruisfontein
# Processing Record 399 of Set 1 | shingu
# Missing field/result... skipping.
# Processing Record 401 of Set 1 | liberec
# Processing Record 402 of Set 1 | ewa beach
# Processing Record 403 of Set 1 | tual
# Processing Record 404 of Set 1 | awbari
# Processing Record 405 of Set 1 | jumla
# Processing Record 406 of Set 1 | charters towers
# Processing Record 407 of Set 1 | dawei
# Processing Record 408 of Set 1 | muzhi
# Processing Record 409 of Set 1 | shubarkuduk
# Processing Record 410 of Set 1 | pacific grove
# Processing Record 411 of Set 1 | shimoda
# Processing Record 412 of Set 1 | saldanha
# Processing Record 413 of Set 1 | hovd
# Missing field/result... skipping.
# Processing Record 415 of Set 1 | grindavik
# Processing Record 416 of Set 1 | anisoc
# Processing Record 417 of Set 1 | ornes
# Processing Record 418 of Set 1 | piranshahr
# Processing Record 419 of Set 1 | ahuimanu
# Missing field/result... skipping.
# Processing Record 421 of Set 1 | banda aceh
# Processing Record 422 of Set 1 | mahibadhoo
# Processing Record 423 of Set 1 | bay roberts
# Missing field/result... skipping.
# Processing Record 425 of Set 1 | nikel
# Processing Record 426 of Set 1 | lodeynoye pole
# Processing Record 427 of Set 1 | nabire
# Processing Record 428 of Set 1 | sorsk
# Processing Record 429 of Set 1 | la macarena
# Missing field/result... skipping.
# Processing Record 431 of Set 1 | kaabong
# Processing Record 432 of Set 1 | alice springs
# Processing Record 433 of Set 1 | mandalgovi
# Processing Record 434 of Set 1 | quime
# Processing Record 435 of Set 1 | cabedelo
# Processing Record 436 of Set 1 | marawi
# Processing Record 437 of Set 1 | bhatapara
# Processing Record 438 of Set 1 | lysva
# Processing Record 439 of Set 1 | poum
# Processing Record 440 of Set 1 | ambulu
# Processing Record 441 of Set 1 | yulara
# Processing Record 442 of Set 1 | mayo
# Processing Record 443 of Set 1 | yeppoon
# Missing field/result... skipping.
# Missing field/result... skipping.
# Processing Record 446 of Set 1 | san juan
# Processing Record 447 of Set 1 | wattegama
# Processing Record 448 of Set 1 | camacha
# Processing Record 449 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 450 of Set 1 | loncoche
# Processing Record 451 of Set 1 | khani
# Processing Record 452 of Set 1 | den helder
# Missing field/result... skipping.
# Processing Record 454 of Set 1 | balkhash
# Processing Record 455 of Set 1 | nagato
# Processing Record 456 of Set 1 | aktash
# Processing Record 457 of Set 1 | batemans bay
# Processing Record 458 of Set 1 | burnie
# Processing Record 459 of Set 1 | ozernovskiy
# Processing Record 460 of Set 1 | ilebo
# Processing Record 461 of Set 1 | escanaba
# Missing field/result... skipping.
# Missing field/result... skipping.
# Processing Record 464 of Set 1 | cockburn town
# Processing Record 465 of Set 1 | inhambane
# Processing Record 466 of Set 1 | sao filipe
# Processing Record 467 of Set 1 | butembo
# Processing Record 468 of Set 1 | neuquen
# Processing Record 469 of Set 1 | hinche
# Processing Record 470 of Set 1 | santa cruz del norte
# Processing Record 471 of Set 1 | karratha
# Processing Record 472 of Set 1 | san patricio
# Processing Record 473 of Set 1 | kotelniki
# Processing Record 474 of Set 1 | gat
# Processing Record 475 of Set 1 | esna
# Processing Record 476 of Set 1 | sobolevo
# Processing Record 477 of Set 1 | kilindoni
# Processing Record 478 of Set 1 | monte patria
# Processing Record 479 of Set 1 | hailar
# Processing Record 480 of Set 1 | palmares do sul
# Processing Record 481 of Set 1 | smirnykh
# Processing Record 482 of Set 1 | kysyl-syr
# Processing Record 483 of Set 1 | xifeng
# Processing Record 484 of Set 1 | fethiye
# Processing Record 485 of Set 1 | markivka
# Processing Record 486 of Set 1 | ortakoy
# Processing Record 487 of Set 1 | bubaque
# Processing Record 488 of Set 1 | watrous
# Processing Record 489 of Set 1 | leo
# Processing Record 490 of Set 1 | cap-aux-meules
# Missing field/result... skipping.
# Processing Record 492 of Set 1 | la ronge
# Processing Record 493 of Set 1 | lagoa
# Processing Record 494 of Set 1 | richards bay
# Processing Record 495 of Set 1 | baghdad
# Processing Record 496 of Set 1 | fortuna
# Processing Record 497 of Set 1 | oroquieta
# Processing Record 498 of Set 1 | okato
# Missing field/result... skipping.
# Processing Record 500 of Set 1 | ulladulla
# Processing Record 501 of Set 1 | vanimo
# Processing Record 502 of Set 1 | panama city
# Processing Record 503 of Set 1 | mezen
# Processing Record 504 of Set 1 | okhotsk
# Processing Record 505 of Set 1 | anadyr
# Processing Record 506 of Set 1 | srednekolymsk
# Processing Record 507 of Set 1 | la primavera
# Processing Record 508 of Set 1 | ewo
# Processing Record 509 of Set 1 | paamiut
# Missing field/result... skipping.
# Processing Record 511 of Set 1 | kaili
# Processing Record 512 of Set 1 | assiniboia
# Processing Record 513 of Set 1 | port blair
# Processing Record 514 of Set 1 | labytnangi
# Processing Record 515 of Set 1 | kynashiv
# Processing Record 516 of Set 1 | tadine
# Processing Record 517 of Set 1 | mugango
# Processing Record 518 of Set 1 | namatanai
# Processing Record 519 of Set 1 | grand gaube
# Processing Record 520 of Set 1 | puerto narino
# Processing Record 521 of Set 1 | port-gentil
# Processing Record 522 of Set 1 | koslan
# Processing Record 523 of Set 1 | sprancenata
# Processing Record 524 of Set 1 | kadoma
# Processing Record 525 of Set 1 | kariba
# Processing Record 526 of Set 1 | sawakin
# Missing field/result... skipping.
# Processing Record 528 of Set 1 | hasaki
# Processing Record 529 of Set 1 | antofagasta
# Processing Record 530 of Set 1 | sao joao da barra
# Processing Record 531 of Set 1 | moyale
# Processing Record 532 of Set 1 | pisco
# Processing Record 533 of Set 1 | seara
# Processing Record 534 of Set 1 | baykit
# Missing field/result... skipping.
# Processing Record 536 of Set 1 | parry sound
# Processing Record 537 of Set 1 | vikulovo
# Missing field/result... skipping.
# Processing Record 539 of Set 1 | voznesenye
# Processing Record 540 of Set 1 | bud
# Processing Record 541 of Set 1 | agropoli
# Processing Record 542 of Set 1 | vardo
# Missing field/result... skipping.
# Processing Record 544 of Set 1 | arica
# Processing Record 545 of Set 1 | orcopampa
# Processing Record 546 of Set 1 | hirara
# Processing Record 547 of Set 1 | bundaberg
# Processing Record 548 of Set 1 | nuuk
# Processing Record 549 of Set 1 | sayyan
# Processing Record 550 of Set 1 | pangody
# Processing Record 551 of Set 1 | morondava
# Processing Record 552 of Set 1 | noumea
# Missing field/result... skipping.
# Processing Record 554 of Set 1 | saquarema
# Processing Record 555 of Set 1 | norman wells
# Processing Record 556 of Set 1 | verkhnevilyuysk
# Processing Record 557 of Set 1 | sept-iles
# Processing Record 558 of Set 1 | grants
# Processing Record 559 of Set 1 | port hawkesbury
# Processing Record 560 of Set 1 | marzuq
# Processing Record 561 of Set 1 | locri
# Processing Record 562 of Set 1 | vanavara
# Processing Record 563 of Set 1 | cap malheureux
# Processing Record 564 of Set 1 | byron bay
# Processing Record 565 of Set 1 | chaparral
# Processing Record 566 of Set 1 | soyo
# Processing Record 567 of Set 1 | toora-khem
# Processing Record 568 of Set 1 | prince rupert
# Processing Record 569 of Set 1 | roswell
# Processing Record 570 of Set 1 | alexandria
# Processing Record 571 of Set 1 | suzhou
# Processing Record 572 of Set 1 | broken hill
# Processing Record 573 of Set 1 | yerofey pavlovich
# Missing field/result... skipping.
# Processing Record 575 of Set 1 | tromso
# Processing Record 576 of Set 1 | ekhabi
# Processing Record 577 of Set 1 | chapais
# Processing Record 578 of Set 1 | norsup
# Missing field/result... skipping.
# Processing Record 580 of Set 1 | husavik
# Processing Record 581 of Set 1 | lorengau
# Processing Record 582 of Set 1 | elmira
# Processing Record 583 of Set 1 | yar-sale
# Processing Record 584 of Set 1 | port augusta
# Processing Record 585 of Set 1 | erzin
# Processing Record 586 of Set 1 | birjand
# Processing Record 587 of Set 1 | taoudenni
# Processing Record 588 of Set 1 | sao felix do xingu
# Processing Record 589 of Set 1 | matamoros
# Processing Record 590 of Set 1 | chifeng
# Processing Record 591 of Set 1 | asekeyevo
# Processing Record 592 of Set 1 | karlstadt
# Processing Record 593 of Set 1 | poya
# Processing Record 594 of Set 1 | zheleznodorozhnyy
# Missing field/result... skipping.
# Processing Record 596 of Set 1 | azul
# Processing Record 597 of Set 1 | kieta
# Processing Record 598 of Set 1 | sola
# Processing Record 599 of Set 1 | mosquera
# Processing Record 600 of Set 1 | montale
# Missing field/result... skipping.
# Processing Record 602 of Set 1 | tatarsk
# Processing Record 603 of Set 1 | port keats
# Processing Record 604 of Set 1 | hay river
# Processing Record 605 of Set 1 | praia
# Processing Record 606 of Set 1 | catamarca
# Processing Record 607 of Set 1 | buala
# Missing field/result... skipping.
# Processing Record 609 of Set 1 | aripuana
# Processing Record 610 of Set 1 | kokopo
# Processing Record 611 of Set 1 | gravdal
# Processing Record 612 of Set 1 | agadez
# Processing Record 613 of Set 1 | kitui
# Processing Record 614 of Set 1 | hobyo
# Processing Record 615 of Set 1 | kemi
# Processing Record 616 of Set 1 | aras
# Processing Record 617 of Set 1 | cururupu
# Processing Record 618 of Set 1 | riyadh
# Processing Record 619 of Set 1 | champasak
# Processing Record 620 of Set 1 | ismailia
# Processing Record 621 of Set 1 | bandarbeyla
# Processing Record 622 of Set 1 | pangnirtung
# Processing Record 623 of Set 1 | indramayu
# Processing Record 624 of Set 1 | kinkala
# Processing Record 625 of Set 1 | khonsa
# Processing Record 626 of Set 1 | beloha
# Processing Record 627 of Set 1 | taltal
# Processing Record 628 of Set 1 | vostok
# Processing Record 629 of Set 1 | japura
# Processing Record 630 of Set 1 | san andres
# Processing Record 631 of Set 1 | college
# Processing Record 632 of Set 1 | jalu
# Processing Record 633 of Set 1 | kiama
# Processing Record 634 of Set 1 | san felipe
# Processing Record 635 of Set 1 | tiarei
# Processing Record 636 of Set 1 | nouadhibou
# Processing Record 637 of Set 1 | fare
# Processing Record 638 of Set 1 | aksha
# Missing field/result... skipping.
# Processing Record 640 of Set 1 | pemangkat
# Processing Record 641 of Set 1 | ferkessedougou
# Processing Record 642 of Set 1 | san policarpo
# Processing Record 643 of Set 1 | haines junction
# Processing Record 644 of Set 1 | tabas
# Missing field/result... skipping.
# Processing Record 646 of Set 1 | chumikan
# Processing Record 647 of Set 1 | maragogi
# ---------------------------------------
# Data Retrieval Complete
# ---------------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Exported the city data into a .csv.
# * Displayed the DataFrame

# %%
weather_dict = {
    "City": city_group,
    "Lat": lat,
    "Lng":lng,
    "Max Temp": max_temp,
    "Humidity" : hum,
    "Cloudiness": cloud,
    "Wind Speed": wind,
    "Country": country,
    "Date": date    
}

# %%
weather_data = pd.DataFrame(weather_dict)
weather_data.head(10)
# Out:
#               City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Chokurdakh  70.63  147.92    -27.67        85           9        1.36
# 1      Port Alfred -33.59   26.89     68.99        87         100       23.62
# 2  Severo-Kuril'sk  50.68  156.12     27.32        90         100       16.42
# 3          Mataura -46.19  168.86     64.99        71           8        4.00
# 4           Khasan  42.43  130.64     29.25        85           2       18.05
# 5        Nishihara  26.18  127.76     71.60        83          40        6.93
# 6           Mehamn  71.04   27.85     32.00        89          75       13.87
# 7           Barrow  71.29 -156.79     12.20        78          90       11.41
# 8         Rantepao  -2.97  119.90     66.33        85         100        2.82
# 9    Krasnosel'kup  65.70   82.47     12.54        96         100       14.41
#
#   Country        Date
# 0      RU  1607285827
# 1      ZA  1607285806
# 2      RU  1607285827
# 3      NZ  1607285827
# 4      RU  1607285828
# 5      JP  1607285793
# 6      NO  1607285808
# 7      US  1607285702
# 8      ID  1607285828
# 9      RU  1607285829

# %%
weather_data.to_csv("weather_data_df.csv", encoding="utf-8", index=False)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
#
# * No cities were found to have a humidity > 100%

# %%
hum_100 = weather_data.loc[weather_data["Humidity"] > 100, :]
hum_40 = weather_data.loc[weather_data['Cloudiness'] <= 40, :]
hum_neg40 = weather_data.loc[weather_data['Cloudiness'] >= -40, :]

# %%
#  Get the indices of cities that have humidity over 100%.
indexNames = weather_data[weather_data['Humidity'] > 100].index



list(hum_100.index)
# Out:
# []

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

clean_city_data = weather_data.drop(indexNames , inplace=False)
clean_city_data.head()
# Out:
#               City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Chokurdakh  70.63  147.92    -27.67        85           9        1.36
# 1      Port Alfred -33.59   26.89     68.99        87         100       23.62
# 2  Severo-Kuril'sk  50.68  156.12     27.32        90         100       16.42
# 3          Mataura -46.19  168.86     64.99        71           8        4.00
# 4           Khasan  42.43  130.64     29.25        85           2       18.05
#
#   Country        Date
# 0      RU  1607285827
# 1      ZA  1607285806
# 2      RU  1607285827
# 3      NZ  1607285827
# 4      RU  1607285828

# %%
# Extract relevant fields from the data frame
# Export the City_Data into a csv

clean_city_data.to_csv("clean_city.csv", encoding="utf-8", index=False)

# %% [markdown]
# ## Plotting the Data
#
# * Plot analysis results including title and axes labels
# * Saved the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
x_values = clean_city_data['Lat']
y_values = clean_city_data['Max Temp']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.title('City Latitude vs. Max Temperature')
plt.show()

# %%
plt.savefig('lat_maxtemp')

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
x_values = clean_city_data['Lat']
y_values = clean_city_data['Humidity']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('City Latitude vs. Humidity')
plt.show()
plt.savefig('lat_humidity')

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
x_values = clean_city_data['Lat']
y_values = clean_city_data['Cloudiness']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('City Latitude vs. Cloudiness')
plt.show()
plt.savefig('lat_cloudiness')

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
x_values = clean_city_data['Lat']
y_values = clean_city_data['Wind Speed']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('City Latitude vs. Wind Speed')
plt.show()
plt.savefig('lat_windspeed')

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
north_hem = weather_data.loc[weather_data["Lat"] > 0, :]
north_hem
# Out:
#                 City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0         Chokurdakh  70.63  147.92    -27.67        85           9
# 2    Severo-Kuril'sk  50.68  156.12     27.32        90         100
# 4             Khasan  42.43  130.64     29.25        85           2
# 5          Nishihara  26.18  127.76     71.60        83          40
# 6             Mehamn  71.04   27.85     32.00        89          75
# ..               ...    ...     ...       ...       ...         ...
# 584   Ferkessédougou   9.60   -5.20     83.12        35          35
# 585    San Policarpo  12.18  125.51     81.48        85         100
# 586  Haines Junction  60.75 -137.51     10.40        85         100
# 587            Tabas  33.60   56.92     48.20        87          56
# 588         Chumikan  54.72  135.31      0.41        85          99
#
#      Wind Speed Country        Date
# 0          1.36      RU  1607285827
# 2         16.42      RU  1607285827
# 4         18.05      RU  1607285828
# 5          6.93      JP  1607285793
# 6         13.87      NO  1607285808
# ..          ...     ...         ...
# 584        3.04      CI  1607285969
# 585        6.49      PH  1607285969
# 586        1.95      CA  1607285917
# 587        1.81      IR  1607285970
# 588       20.78      RU  1607285970
#
# [392 rows x 9 columns]

# %%
south_hem = weather_data.loc[weather_data["Lat"] < 0, :]
south_hem
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 1    Port Alfred -33.59   26.89     68.99        87         100       23.62
# 3        Mataura -46.19  168.86     64.99        71           8        4.00
# 8       Rantepao  -2.97  119.90     66.33        85         100        2.82
# 10       Te Anau -45.42  167.72     56.66        74           4        7.61
# 13     Geraldton -28.77  114.60     57.20        82           0        9.17
# ..           ...    ...     ...       ...       ...         ...         ...
# 573       Japura  -0.32  102.35     73.58        92         100        1.41
# 577        Kiama -34.68  150.87     63.00        69           0        1.99
# 579       Tiarei -17.53 -149.33     75.20        88          75        6.93
# 581         Fare -16.70 -151.02     81.46        72         100       11.39
# 589     Maragogi  -9.01  -35.22     78.67        72           8       10.51
#
#     Country        Date
# 1        ZA  1607285806
# 3        NZ  1607285827
# 8        ID  1607285828
# 10       NZ  1607285829
# 13       AU  1607285829
# ..      ...         ...
# 573      ID  1607285967
# 577      AU  1607285967
# 579      PF  1607285968
# 581      PF  1607285807
# 589      BR  1607285970
#
# [198 rows x 9 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
from scipy import stats

x_values = north_hem['Lat']
y_values = north_hem['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,80),fontsize=16,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.show()

print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.7307082150795542

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = south_hem['Lat']
y_values = south_hem['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-40,40),fontsize=16,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.show()

print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.21931787981829276

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = north_hem['Lat']
y_values = north_hem['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,80),fontsize=16,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()

print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.15168099597310436

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = south_hem['Lat']
y_values = south_hem['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-40,60),fontsize=16,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()

print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.14894467824948088

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = north_hem['Lat']
y_values = north_hem['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,60),fontsize=16,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.show()

print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.044220008500787805

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = south_hem['Lat']
y_values = south_hem['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-40,50),fontsize=16,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.show()

print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.10112281901355356

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = north_hem['Lat']
y_values = north_hem['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,15),fontsize=16,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.show()

print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.038738654345847834

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = south_hem['Lat']
y_values = south_hem['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-40,10),fontsize=16,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.show()

print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.07693127364883388
